# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv("data/BigBasket Products.csv")
data_2 = pd.read_csv("data/Luxury watch.csv")
data_3 = pd.read_csv("data/sephora_website_dataset.csv")
data_4 = pd.read_csv("data/myntra_products_catalog.csv")
data_5 = pd.read_csv("data/smartwatches.csv")
data_6 = pd.read_csv("data/TV_Final.csv")
data_7 = pd.read_csv("data/archive-8/Flipkart_Mobiles.csv")

# %%
data_1.head(10)
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
# 5      6                  Germ - Removal Multipurpose Wipes
# 6      7                                       Multani Mati
# 7      8                  Hand Sanitizer - 70% Alcohol Base
# 8      9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9     10               Scrub Pad - Anti- Bacterial, Regular
#
#                  category            sub_category              brand  \
# 0        Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets   Storage & Accessories         Mastercook
# 2    Cleaning & Household             Pooja Needs                Trm
# ...

# %%
data_2.head(10)
# Out:
#               Brand        Model    Case Material   Strap Material  \
# 0             Rolex   Submariner  Stainless Steel  Stainless Steel
# 1             Omega    Seamaster         Titanium           Rubber
# 2         Tag Heuer      Carrera  Stainless Steel          Leather
# 3         Breitling    Navitimer  Stainless Steel  Stainless Steel
# 4           Cartier    Tank Solo  Stainless Steel          Leather
# 5  Jaeger-LeCoultre      Reverso  Stainless Steel          Leather
# 6             Seiko      Prospex  Stainless Steel           Rubber
# 7           Citizen    Promaster  Stainless Steel  Stainless Steel
# 8            Tissot     Le Locle  Stainless Steel          Leather
# 9          Hamilton  Khaki Field  Stainless Steel          Leather
#
#   Movement Type Water Resistance  Case Diameter (mm)  Case Thickness (mm)  \
# 0     Automatic       300 meters                40.0                13.00
# 1     Automatic       600 meters                43.5                14.47
# ...

# %%
data_3.head(10)
# Out:
#         id           brand               category  \
# 0  2218774  Acqua Di Parma              Fragrance
# 1  2044816  Acqua Di Parma                Cologne
# 2  1417567  Acqua Di Parma                Perfume
# 3  1417617  Acqua Di Parma                Perfume
# 4  2218766  Acqua Di Parma              Fragrance
# 5  1417609  Acqua Di Parma                Perfume
# 6  1638832  Acqua Di Parma                Perfume
# 7  1284462  Acqua Di Parma                Cologne
# 8  2221588  Acqua Di Parma  Body Mist & Hair Mist
# 9  2221596  Acqua Di Parma                Perfume
#
#                              name            size  rating  number_of_reviews  \
# 0  Blu Mediterraneo MINIATURE Set  5 x 0.16oz/5mL     4.0                  4
# 1                         Colonia   0.7 oz/ 20 mL     4.5                 76
# 2                Arancia di Capri    5 oz/ 148 mL     4.5                 26
# 3                Mirto di Panarea   2.5 oz/ 74 mL     4.5                 23
# ...

# %%
data_4.head(10)
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
# 5   10014361    SHOWOFF Men Brown Solid Slim Fit Regular Shorts      SHOWOFF
# 6   10017869        Parx Men Blue Slim Fit Checked Casual Shirt         Parx
# 7   10009695  SPYKAR Women Burgundy Alexa Super Skinny Fit H...       SPYKAR
# 8   10000571  Parx Men Brown Tapered Fit Solid Regular Trousers         Parx
# 9   10017421                DKNY Unisex Black Large Trolley Bag         DKNY
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# ...

# %%
data_5.head(10)
# Out:
#    Unnamed: 0       Brand  Current Price  Original Price  Discount Percentage  \
# 0           0       noise        82990.0         89900.0             7.686318
# 1           1  fire-boltt         3799.0         16999.0            77.651627
# 2           2        boat         1999.0          7990.0            74.981227
# 3           3  fire-boltt         1799.0         19999.0            91.004550
# 4           4       noise         1599.0          4999.0            68.013603
# 5           5       noise         1499.0          3999.0            62.515629
# 6           6       noise         1999.0          4999.0            60.012002
# 7           7       noise         1799.0          3999.0            55.013753
# 8           8       noise         1999.0          6499.0            69.241422
# 9           9       noise         1999.0          5999.0            66.677780
#
#    Rating  Number OF Ratings                              Model Name  \
# ...

# %%
data_6.head(10)
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
# 5  OnePlus         HD LED     32          15999           19999
# 6  OnePlus    Full HD LED     43          25999           29999
# 7     TCL    Ultra HD LED     65          57999          119990
# 8      Mi     Full HD LED     40          21999           29999
# 9  realme    Ultra HD LED     43          26999           32999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3
# 5          Android     4.3
# 6          Android     4.3
# 7          Android     4.2
# ...

# %%
data_7.head(10)
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5          11990
# 5  OPPO   A53   Electric Black   6 GB  128 GB     4.3          13990
# 6  OPPO   A12        Deep Blue   4 GB   64 GB     4.4          10490
# 7  OPPO   A12            Black   3 GB   32 GB     4.4           9490
# 8  OPPO   A12             Blue   3 GB   32 GB     4.4           9490
# 9  OPPO   A12   Flowing Silver   3 GB   32 GB     4.4           9490
#
#    Original Price
# 0           15990
# 1           15990
# 2           17990
# 3           17990
# 4           15990
# 5           17990
# 6           11990
# 7           10990
# 8           10990
# ...

# %% [markdown]
# ### After going through the above data I undersand that different categories have different specifics that need to be displayed for each product.

# %%
data_2['category'] = 'Watches'

# %%
data_2.head(10)
# Out:
#               Brand        Model    Case Material   Strap Material  \
# 0             Rolex   Submariner  Stainless Steel  Stainless Steel
# 1             Omega    Seamaster         Titanium           Rubber
# 2         Tag Heuer      Carrera  Stainless Steel          Leather
# 3         Breitling    Navitimer  Stainless Steel  Stainless Steel
# 4           Cartier    Tank Solo  Stainless Steel          Leather
# 5  Jaeger-LeCoultre      Reverso  Stainless Steel          Leather
# 6             Seiko      Prospex  Stainless Steel           Rubber
# 7           Citizen    Promaster  Stainless Steel  Stainless Steel
# 8            Tissot     Le Locle  Stainless Steel          Leather
# 9          Hamilton  Khaki Field  Stainless Steel          Leather
#
#   Movement Type Water Resistance  Case Diameter (mm)  Case Thickness (mm)  \
# 0     Automatic       300 meters                40.0                13.00
# 1     Automatic       600 meters                43.5                14.47
# ...

# %%
data_4['category'] = 'Fashion & Clothing'

# %%
data_5['category'] = 'Smartwatches'

# %%
data_5.drop(labels = 'Unnamed: 0',axis =1,inplace = True)

# %%
data_6['category'] = 'Televisions'

# %%
data_7['category'] = 'Smartphones'

# %%
data_1.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
data_1.shape
# Out:
# (27555, 10)

# %%
data_1['rating']
# Out:
# 0        4.1
# 1        2.3
# 2        3.4
# 3        3.7
# 4        4.4
#         ...
# 27550    3.9
# 27551    4.0
# 27552    3.8
# 27553    4.2
# 27554    4.5
# Name: rating, Length: 27555, dtype: float64

# %%
data_1['rating'] = data_1['rating'].fillna(0)

# %%
data_1.isnull().sum()
# Out:
# index             0
# product           1
# category          0
# sub_category      0
# brand             1
# sale_price        0
# market_price      0
# type              0
# rating            0
# description     115
# dtype: int64

# %%
data_1.dropna(inplace = True,axis = 0)

# %%
data_1.isnull().sum()
# Out:
# index           0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
data_2.isnull().sum()
# Out:
# Brand                   0
# Model                   0
# Case Material           0
# Strap Material          0
# Movement Type           0
# Water Resistance        0
# Case Diameter (mm)      0
# Case Thickness (mm)     0
# Band Width (mm)         0
# Dial Color              0
# Crystal Material        0
# Complications           0
# Power Reserve          14
# Price (USD)             1
# category                0
# dtype: int64

# %%
data_2.shape
# Out:
# (507, 15)

# %%
data_2.dropna(axis= 0, inplace = True)

# %%
data_3.isnull().sum()
# Out:
# id                        0
# brand                     0
# category                  0
# name                      0
# size                      0
# rating                    0
# number_of_reviews         0
# love                      0
# price                     0
# value_price               0
# URL                       0
# MarketingFlags            0
# MarketingFlags_content    0
# options                   0
# details                   0
# how_to_use                0
# ingredients               0
# online_only               0
# exclusive                 0
# limited_edition           0
# limited_time_offer        0
# dtype: int64

# %%
data_4.isnull().sum()
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# category          0
# dtype: int64

# %%
data_4.shape
# Out:
# (12491, 9)

# %%
data_4.dropna(axis =0,inplace = True)

# %%
data_5.isnull().sum()
# Out:
# Brand                    0
# Current Price           10
# Original Price          73
# Discount Percentage     73
# Rating                   6
# Number OF Ratings       59
# Model Name              35
# Dial Shape             123
# Strap Color            123
# Strap Material          69
# Touchscreen             37
# Battery Life (Days)     32
# Bluetooth                6
# Display Size            30
# Weight                 186
# category                 0
# dtype: int64

# %%
data_5.shape
# Out:
# (450, 16)

# %%
data_5[data_5['Original Price'].isnull()]
# Out:
#        Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 49   samsung            NaN             NaN                  NaN     4.3
# 54    garmin            NaN             NaN                  NaN     3.7
# 56    garmin            NaN             NaN                  NaN     5.0
# 58    garmin            NaN             NaN                  NaN     3.8
# 69      dizo            NaN             NaN                  NaN     2.4
# ..       ...            ...             ...                  ...     ...
# 312   fossil        16495.0             NaN                  NaN     4.7
# 314   fossil        13995.0             NaN                  NaN     3.8
# 315   fossil        13495.0             NaN                  NaN     4.4
# 316   fossil        13495.0             NaN                  NaN     4.7
# 350  gizmore         6999.0             NaN                  NaN     4.7
#
#      Number OF Ratings                                         Model Name  \
# ...

# %%
data_5['Discount Percentage'].value_counts()
# Out:
# 66.677780    12
# 64.012803     7
# 55.013753     6
# 50.008335     5
# 60.006001     5
#              ..
# 21.430102     1
# 56.698557     1
# 6.666889      1
# 10.000250     1
# 62.495312     1
# Name: Discount Percentage, Length: 271, dtype: int64

# %%
data_5.sort_values(by = 'Brand')
# Out:
#          Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 240    amazfit         9999.0         17999.0            44.446914     4.5
# 250    amazfit         7200.0         14999.0            51.996800     4.0
# 239    amazfit         4499.0          5999.0            25.004167     4.1
# 249    amazfit         2999.0          5999.0            50.008335     3.8
# 248    amazfit        19999.0         23999.0            16.667361     4.3
# ..         ...            ...             ...                  ...     ...
# 101  zebronics         1399.0          3999.0            65.016254     4.0
# 102  zebronics         1799.0          6499.0            72.318818     3.8
# 103  zebronics         3499.0         11499.0            69.571267     4.2
# 392  zebronics         2999.0          7999.0            62.507813     3.5
# 98   zebronics         2099.0          7999.0            73.759220     3.8
#
# ...

# %%
data_5.groupby(by = 'Brand').mean()
# Out:
#             Current Price  Original Price  Discount Percentage    Rating  \
# Brand
# amazfit      10084.785714    15070.428571            34.312128  4.142857
# ambrane       1896.181818     5035.363636            61.198191  4.081818
# apple        43161.307692    34400.000000             1.688613  4.553846
# boat          2094.161290     7387.935484            71.584178  3.996774
# crossbeats    4249.000000    11249.000000            61.672369  4.100000
# dizo          3010.708333     5526.916667            42.867443  3.876000
# fire-boltt    3280.389831    10002.389831            64.698938  3.475439
# fitbit       17698.100000    20999.000000            23.148494  4.445000
# fossil       15232.666667    20495.000000            38.287837  4.066667
# garmin       45226.842105    49657.931034            16.496675  4.441463
# gizmore       2320.739130     6249.000000            65.601404  3.859091
# hammer        1799.000000     4999.000000            64.012803  3.600000
# ...

# %%
data_5[data_5['Brand']=='amazfit']
# Out:
#        Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 237  amazfit         3999.0          5999.0            33.338890     4.2
# 238  amazfit         7499.0         16999.0            55.885640     4.3
# 239  amazfit         4499.0          5999.0            25.004167     4.1
# 240  amazfit         9999.0         17999.0            44.446914     4.5
# 241  amazfit        16999.0         23999.0            29.167882     4.3
# 242  amazfit         4999.0          6999.0            28.575511     4.1
# 243  amazfit        13999.0         18999.0            26.317175     4.1
# 244  amazfit        13999.0         18999.0            26.317175     4.1
# 245  amazfit        18999.0         25999.0            26.924112     4.2
# 246  amazfit         6999.0          9999.0            30.003000     3.7
# 247  amazfit         8999.0         13999.0            35.716837     4.3
# 248  amazfit        19999.0         23999.0            16.667361     4.3
# ...

# %%
data_5[data_5['Brand']=='amazfit']['Discount Percentage']
# Out:
# 237    33.338890
# 238    55.885640
# 239    25.004167
# 240    44.446914
# 241    29.167882
# 242    28.575511
# 243    26.317175
# 244    26.317175
# 245    26.924112
# 246    30.003000
# 247    35.716837
# 248    16.667361
# 249    50.008335
# 250    51.996800
# Name: Discount Percentage, dtype: float64

# %%
data_5[data_5['Brand']=='amazfit']['Discount Percentage'].plot(y='Discount Percentage',style = '.-')
plt.xticks(np.arange(min(data_5[data_5['Brand']=='amazfit'].index), max(data_5[data_5['Brand']=='amazfit'].index)+1, 1))
plt.xlabel('product id')
plt.show()

# %%
data_5['Brand'].unique()
# Out:
# array(['noise', 'fire-boltt', 'boat', 'honor', 'crossbeats', 'samsung',
#        'garmin', 'huawei', 'dizo', 'gizmore', 'ambrane', 'zebronics',
#        'pebble', 'hammer', 'apple', 'fitbit', 'amazfit', 'fossil'],
#       dtype=object)

# %%
for i in data_5['Brand'].unique():
    data_5[data_5['Brand']==i]['Discount Percentage'].plot(y='Discount Percentage',style = '.-')
    plt.xticks(np.arange(min(data_5[data_5['Brand']==i].index), max(data_5[data_5['Brand']==i].index)+1, 1))
    plt.xlabel('product id')
    plt.title(i)
    plt.show()

# %% [markdown]
# ### As we can observe that the discount percentage within a brand is variable. Since there missing values in discount percentage and prices and we cannot identify a way to fill it i will drop it

# %%
data_5.isnull().sum()
# Out:
# Brand                    0
# Current Price           10
# Original Price          73
# Discount Percentage     73
# Rating                   6
# Number OF Ratings       59
# Model Name              35
# Dial Shape             123
# Strap Color            123
# Strap Material          69
# Touchscreen             37
# Battery Life (Days)     32
# Bluetooth                6
# Display Size            30
# Weight                 186
# category                 0
# dtype: int64

# %%
data_5.shape
# Out:
# (450, 16)

# %%
data_5.dropna(axis=0,inplace = True)

# %%
data_5
# Out:
#           Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 122       apple        29650.0         29900.0             0.836120     4.5
# 128       apple        44730.0         44900.0             0.378619     4.6
# 131       apple        49666.0         50900.0             2.424361     4.5
# 137       apple        32899.0         32900.0             0.003040     4.6
# 161       noise         1499.0          4999.0            70.014003     4.1
# ..          ...            ...             ...                  ...     ...
# 401   zebronics         1799.0          3999.0            55.013753     4.2
# 402   zebronics         3499.0          7999.0            56.257032     1.0
# 403   zebronics         1399.0          4499.0            68.904201     4.0
# 409   zebronics         1499.0          2999.0            50.016672     3.1
# 422  fire-boltt         3449.0          9999.0            65.506551     3.8
#
# ...

# %%
data_6.isnull().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# category              0
# dtype: int64

# %%
data_6.shape
# Out:
# (912, 8)

# %%
data_6.dropna(subset = 'Operating System',inplace = True,axis =0)

# %%
data_7.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory             43
# Storage            39
# Rating            144
# Selling Price       0
# Original Price      0
# category            0
# dtype: int64

# %%
data_7.shape
# Out:
# (3114, 9)

# %%
data_7.dropna(subset = ['Memory','Storage'],axis = 0,inplace = True)

# %%
data_7.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory              0
# Storage             0
# Rating            135
# Selling Price       0
# Original Price      0
# category            0
# dtype: int64

# %%
data_1.to_csv('db-data/data_1.csv')

# %%
data_2.to_csv('db-data/data_2.csv')

# %%
data_3.to_csv('db-data/data_3.csv')

# %%
data_4.to_csv('db-data/data_4.csv',sep = ';')

# %%
data_5.to_csv('db-data/data_5.csv')

# %%
data_6.to_csv('db-data/data_6.csv')

# %%
data_7.to_csv('db-data/data_7.csv')

# %%
data_1['category'].unique()
# Out:
# array(['Beauty & Hygiene', 'Kitchen, Garden & Pets',
#        'Cleaning & Household', 'Gourmet & World Food',
#        'Foodgrains, Oil & Masala', 'Snacks & Branded Foods', 'Beverages',
#        'Bakery, Cakes & Dairy', 'Baby Care', 'Fruits & Vegetables',
#        'Eggs, Meat & Fish'], dtype=object)
